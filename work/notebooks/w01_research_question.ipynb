# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 2 — Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should be reviewed first for a possible refresh or improvement.
# Action: The marketing/content team uses the ranked list to investigate and decide whether to refresh, improve, protect, consolidate, monitor, or leave a page unchanged.
# Cost of a wrong call: A false positive wastes the team's limited time on a low-value page, while a false negative can cause the team to miss an important page that needs attention and potentially lose valuable traffic or opportunity.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 pages. 16,262 pages (54.21%) are currently showing a downward trend, while 16,726 pages (55.75%) have at least 500 impressions over the last 90 days. This suggests there is a large enough set of pages with measurable search visibility and declining movement to investigate a ranking system that can help prioritize which pages should be reviewed first.

# %%
# !git clone https://github.com/muhammadfaseehkhattak/FlyRank-ML-Internship.git
# Out:
# fatal: destination path 'FlyRank-ML-Internship' already exists and is not an empty directory.

# %%
# !ls FlyRank-ML-Internship/data/raw/
# Out:
# content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv(
    "FlyRank-ML-Internship/data/raw/content_refresh_anonymized.csv"
)

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %%
print(df[[
    "impressions_90d",
    "days_since_last_update",
    "content_age_days",
    "trend_direction"
]].describe())
# Out:
#        impressions_90d  days_since_last_update  content_age_days
# count     30000.000000            30000.000000       30000.00000
# mean       5200.366300               46.098300         256.16780
# std       16838.019547               42.078709         132.70793
# min           1.000000                1.000000          90.00000
# 25%          81.000000               20.000000         132.00000
# 50%         731.000000               20.000000         236.00000
# 75%        3615.250000              104.000000         333.00000
# max      517715.000000              373.000000         564.00000

# %%
stale_visible = (
    (df["days_since_last_update"] >= 180) &
    (df["impressions_90d"] >= 500)
)

print("Stale + visible pages:", stale_visible.sum())
print("Percentage of dataset:", round(stale_visible.mean() * 100, 2), "%")
# Out:
# Stale + visible pages: 17
# Percentage of dataset: 0.06 %

# %%
declining = df["trend_direction"].str.lower().eq("down")

print("Declining pages:", declining.sum())
print("Percentage declining:", round(declining.mean() * 100, 2), "%")
# Out:
# Declining pages: 16262
# Percentage declining: 54.21 %

# %%
visible = df["impressions_90d"] >= 500

print("Pages with >=500 impressions:", visible.sum())
print("Percentage:", round(visible.mean() * 100, 2), "%")
# Out:
# Pages with >=500 impressions: 16726
# Percentage: 55.75 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim
#
# My work can identify patterns in the available data and rank pages based on signals associated with declining performance or content opportunity. The result can be used as decision support to help a marketing team prioritize which pages should be reviewed first.
#
# I can say that the data observes certain relationships and that the model provides directional signals about which pages may deserve attention.
#
# What I cannot claim
#
# I cannot claim that refreshing a page will definitely improve its performance, because this analysis does not prove causation. I also cannot claim that the model predicts Google's ranking algorithm or that it knows exactly why Google ranks a page in a certain position.
#
# The model is a prioritization tool, not a guarantee. Human review is still required before taking action.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
